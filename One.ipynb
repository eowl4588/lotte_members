# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
% cd /content/drive/MyDrive/LPAY_DATA/commit_folder/lotte_members
# Out:
# /content/drive/.shortcut-targets-by-id/102BbKNvpFxf2GjBqwgiZLo6oKeUrXpK0/LPAY_DATA/commit_folder/lotte_members

# %%
! git config --global user.email 'bsm021031@naver.com'
! git config --global user.name 'bsm021031'

# %%
! git add .

# %%
! git commit -m "T_first"
# Out:
# [main 3ef1303] T_first
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 One.ipynb

# %%
! git push -u origin main
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 2.39 KiB | 305.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/bsm021031/lotte_members.git
#    6833336..3ef1303  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
